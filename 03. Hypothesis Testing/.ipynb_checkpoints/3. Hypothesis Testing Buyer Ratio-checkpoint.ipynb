# %% [markdown]
# # Hypothesis Testing Exercise

# %% [markdown]
# Sales of products in four different regions is tabulated for males and females. Find if male-female buyer rations are similar across regions.

# %%
# importing basic libraries
import pandas as pd
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# loading data
df = pd.read_csv(r'BuyerRatio.csv')

# %%
df
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
f, axes = plt.subplots(2, 2, figsize=(12,6))

sns.barplot(x="Observed Values", y="East", data=df, ax = axes[0,0])
sns.barplot(x="Observed Values", y="West", data=df, ax = axes[0,1])
sns.barplot(x="Observed Values", y="North", data=df, ax = axes[1,0])
sns.barplot(x="Observed Values", y="South", data=df, ax = axes[1,1]);

# %%
# Creating Contingency table
data = [[50, 142, 131, 70], [435, 1523, 1356, 750]]

# %%
data
# Out:
# [[50, 142, 131, 70], [435, 1523, 1356, 750]]

# %% [markdown]
# ### Applying Chi-Square on contingency table to convert observed value into expected value

# %%
stat, p_value, dof, expected = stats.chi2_contingency(data)

print(stat)
print(p_value)
print(dof)
print(expected)
# Out:
# 1.595945538661058
# 0.6603094907091882
# 3
# [[  42.76531299  146.81287862  131.11756787   72.30424052]
#  [ 442.23468701 1518.18712138 1355.88243213  747.69575948]]

# %%
stats.chi2_contingency(data)
# Out:
# Chi2ContingencyResult(statistic=1.595945538661058, pvalue=0.6603094907091882, dof=3, expected_freq=array([[  42.76531299,  146.81287862,  131.11756787,   72.30424052],
#        [ 442.23468701, 1518.18712138, 1355.88243213,  747.69575948]]))

# %%
observed = np.array([50, 142, 131, 70, 435, 1523, 1356, 750])
expected = np.array([42.76531299,  146.81287862,  131.11756787, 72.30424052, 442.23468701, 1518.18712138, 1355.88243213, 747.69575948])

# %%
print(f"p-value for Chi-Square Test: {p_value}")
print(f"Test Statistics : {stat}")
# Out:
# p-value for Chi-Square Test: 0.6603094907091882
# Test Statistics : 1.595945538661058

# %% [markdown]
# # Compare P value with Alpha

# %%
alpha = 0.05

if p_value < alpha:
    print('We are rejecting Null Hypothesis')
else:
    print('We are accepting Null Hypothesis')
# Out:
# We are accepting Null Hypothesis

# %%
# Hence we fail to reject Null Hypothesis
